# %% [markdown]
# # Stability Plotter

# %% [markdown]
# Notebook which plots stability results.

# %% [markdown]
# ## Mount Drive

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
root = '/content/drive/My Drive/Project/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Install Bokeh

# %%
# bokeh intstall
#!pip install bokeh
#!pip install selenium

# %% [markdown]
# ## Plot

# %% [markdown]
# Add files analyse, utils and preferences to path which are stored in root directory.

# %%
import sys
sys.path.append(root + 'Stability Data/')
from analyse import MSexperiment,SmoothMSexperiment

# %% [markdown]
# Create plot saves as html file and dislays it.

# %%
exp = SmoothMSexperiment(mat_file=root +'Stability Data/longrun.mat', save_dir=root + 'Plots')
try:
    exp.plot(mt_list=[7499,3350,188.4,19.95,0.5623])
except:
    pass
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from analyse import MSexperiment,SmoothMSexperiment
exp = MSexperiment(mat_file=root +'Stability Data/longrun.mat', save_dir=root + 'Plots')
try:
    exp.plot(mt_list=[7499,3350,188.4,19.95,0.5623])
except:
    pass
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Note: I am yet to solve following error which stops the saving of the plot as a png and svg file:
#
# RuntimeError: Neither firefox and geckodriver nor a variant of chromium browser and chromedriver are available on system PATH.
#
# Note: To save as png click save icon in displayed figure.
